# %% [markdown]
# <a href="https://colab.research.google.com/github/trong-khanh-1109/CS114.L22.KHCL/blob/main/Pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import os

# %%
FJoin = os.path.join
FJoin
# Out:
# <function posixpath.join>

# %%
def getLink(path):
    index = 0
    list_folder = [FJoin(path, f) for f in sorted(os.listdir(path))]
    for f in list_folder:
        list_img = [FJoin(f, img_id) for img_id in sorted(os.listdir(f))]
        for img_link in list_img:
          index += 1
    return index

# %%
train_path = '/content/drive/MyDrive/Data_Final_Project/Train'
vali_path = '/content/drive/MyDrive/Data_Final_Project/Validation'
test_path = '/content/drive/MyDrive/Data_Final_Project/Test'
count_train = getLink(train_path)
count_vali = getLink(vali_path)
count_test = getLink(test_path)
print(count_train)
print(count_vali)
print(count_test)
# Out:
# 19278
# 4863
# 5427

# %%
count_train = 19278
count_vali = 4863
count_test = 5384
count_tong = count_train + count_vali + count_test
count_tong
# Out:
# 29525

# %%
per_train = (count_train / count_tong) * 100
per_vali = (count_vali / count_tong) * 100
per_test = (count_test / count_tong) * 100

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 10,10

# %%
percents = [per_train, per_vali, per_test]
labels_ = ["Train", "Validation", "Test"]
#colors = ["blue" , "yellow" , "red"]
plt.pie(percents, labels= labels_, autopct='%1.3f%%', wedgeprops={'edgecolor': 'white', 'linewidth': 1.5})
plt.axis('equal')
plt.legend(title = "List data")
plt.show()
